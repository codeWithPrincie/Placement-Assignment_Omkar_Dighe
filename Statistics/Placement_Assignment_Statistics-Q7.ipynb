# %% [markdown]
# **Q-7.**
#
# **The equations of two lines of regression, obtained in a correlation analysis
# between variables X and Y are as follows:**
#
# **and . 2X + 3 − 8 = 0 2Y + X − 5 = 0 The variance of X = 4 Find the
# a. Variance of Y**
#
# **b. Coefficient of determination of C and Y**
#
# **c. Standard error of estimate of X on Y and of Y on X.**

# %% [markdown]
# **Ans.**
#
# To calculate the variance of Y, we need to find the equation of the regression line for Y.
#
# The equation of the regression line for Y can be obtained by rearranging the equation of the line of regression between X and Y, which is given as:
#
# 2Y + X - 5 = 0
#
# Rearranging this equation, we get:
#
# 2Y = -X + 5
#
# Y = (-1/2)X + (5/2)
#
# Now we have the equation of the regression line for Y. We can use this equation to calculate the variance of Y.
#
# **a. Variance of Y:**
#
# The variance of Y can be calculated using the formula:
#
# var(Y) = var(X) * (slope of regression line for Y)^2
#
# Since the variance of X is given as 4, we can substitute the values into the formula:
#
# var(Y) = 4 * (-1/2)^2
#
# var(Y) = 4 * 1/4
#
# var(Y) = 1
#
# Therefore, the variance of Y is 1.
#
# **b. Coefficient of determination of X and Y:**
#
# The coefficient of determination (R^2) represents the proportion of the total variation in Y that can be explained by the regression of Y on X.
#
# In this case, the coefficient of determination of X and Y is the same as the squared correlation coefficient between X and Y, which can be calculated as the square of the slope of the regression line for Y:
#
# R^2 = (slope of regression line for Y)^2
#
# R^2 = (-1/2)^2
#
# R^2 = 1/4
#
# Therefore, the coefficient of determination of X and Y is 1/4.
#
# **c. Standard error of estimate of X on Y and Y on X:**
#
# The standard error of estimate represents the average distance between the observed values and the predicted values from the regression line.
#
# For the standard error of estimate of X on Y, we use the formula:
#
# standard error of estimate of X on Y = sqrt((1 - R^2) * var(X))
#
# standard error of estimate of X on Y = sqrt((1 - 1/4) * 4)
#
# standard error of estimate of X on Y = sqrt(3)
#
# Similarly, for the standard error of estimate of Y on X, we use the formula:
#
# standard error of estimate of Y on X = sqrt((1 - R^2) * var(Y))
#
# standard error of estimate of Y on X = sqrt((1 - 1/4) * 1)
#
# standard error of estimate of Y on X = sqrt(3/4)
#
# Therefore, the standard error of estimate of X on Y is sqrt(3), and the standard error of estimate of Y on X is sqrt(3/4).
